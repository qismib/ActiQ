# %%
# !sudo apt-get update
# !sudo apt-get install -y xvfb ffmpeg freeglut3-dev
# !pip install 'imageio==2.4.0'
# !pip install pyvirtualdisplay
# !pip install tf-agents
# !pip install pyglet
# !pip install tf-keras

import os
os.environ['TF_USE_LEGACY_KERAS'] = '1'

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import base64
import imageio
import IPython
import matplotlib
import matplotlib.pyplot as plt
import PIL.Image
import pyvirtualdisplay

import tensorflow as tf

from tf_agents.agents.categorical_dqn import categorical_dqn_agent
from tf_agents.drivers import dynamic_step_driver
from tf_agents.environments import suite_gym
from tf_agents.environments import tf_py_environment
from tf_agents.eval import metric_utils
from tf_agents.metrics import tf_metrics
from tf_agents.networks import categorical_q_network
from tf_agents.policies import random_tf_policy
from tf_agents.replay_buffers import tf_uniform_replay_buffer
from tf_agents.trajectories import trajectory
from tf_agents.utils import common

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 257 kB in 2s (140 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# freeglut3-dev is already the newest version (2.8.1-6).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.12).
# 0 upgraded, 0 newly installed, 0 to remove and 52 not upgraded.
# Requirement already satisfied: imageio==2.4.0 in /usr/local/lib/python3.10/dist-packages (2.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from imageio==2.4.0) (1.26.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from imageio==2.4.0) (10.4.0)
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.10/dist-packages (3.0)
# Requirement already satisfied: tf-agents in /usr/local/lib/python3.10/dist-packages (0.19.0)
# Requirement already satisfied: absl-py>=0.6.1 in /usr/local/lib/python3.10/dist-packages (from tf-agents) (1.4.0)
# Requirement already satisfied: cloudpickle>=1.3 in /usr/local/lib/python3.10/dist-packages (from tf-agents) (3.1.0)
# Requirement already satisfied: gin-config>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from tf-agents) (0.5.0)
# Requirement already satisfied: gym<=0.23.0,>=0.17.0 in /usr/local/lib/python3.10/dist-packages (from tf-agents) (0.23.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from tf-agents) (1.26.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from tf-agents) (10.4.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from tf-agents) (1.16.0)
# Requirement already satisfied: protobuf>=3.11.3 in /usr/local/lib/python3.10/dist-packages (from tf-agents) (3.20.3)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.10/dist-packages (from tf-agents) (1.16.0)
# Requirement already satisfied: typing-extensions==4.5.0 in /usr/local/lib/python3.10/dist-packages (from tf-agents) (4.5.0)
# Requirement already satisfied: pygame==2.1.3 in /usr/local/lib/python3.10/dist-packages (from tf-agents) (2.1.3)
# Requirement already satisfied: tensorflow-probability~=0.23.0 in /usr/local/lib/python3.10/dist-packages (from tf-agents) (0.23.0)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym<=0.23.0,>=0.17.0->tf-agents) (0.0.8)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from tensorflow-probability~=0.23.0->tf-agents) (4.4.2)
# Requirement already satisfied: gast>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow-probability~=0.23.0->tf-agents) (0.6.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from tensorflow-probability~=0.23.0->tf-agents) (0.1.8)
# Requirement already satisfied: pyglet in /usr/local/lib/python3.10/dist-packages (2.0.18)
# Requirement already satisfied: tf-keras in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: tensorflow<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tf-keras) (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.18,>=2.17->tf-keras) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.18,>=2.17->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.18,>=2.17->tf-keras) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.18,>=2.17->tf-keras) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.18,>=2.17->tf-keras) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.18,>=2.17->tf-keras) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.18,>=2.17->tf-keras) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.18,>=2.17->tf-keras) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.18,>=2.17->tf-keras) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.18,>=2.17->tf-keras) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.18,>=2.17->tf-keras) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.18,>=2.17->tf-keras) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.18,>=2.17->tf-keras) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.18,>=2.17->tf-keras) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.18,>=2.17->tf-keras) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.18,>=2.17->tf-keras) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.18,>=2.17->tf-keras) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.18,>=2.17->tf-keras) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.18,>=2.17->tf-keras) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.18,>=2.17->tf-keras) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.18,>=2.17->tf-keras) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.18,>=2.17->tf-keras) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow<2.18,>=2.17->tf-keras) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (13.9.3)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow<2.18,>=2.17->tf-keras) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow<2.18,>=2.17->tf-keras) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow<2.18,>=2.17->tf-keras) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow<2.18,>=2.17->tf-keras) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow<2.18,>=2.17->tf-keras) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow<2.18,>=2.17->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow<2.18,>=2.17->tf-keras) (3.0.6)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow<2.18,>=2.17->tf-keras) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow<2.18,>=2.17->tf-keras) (0.1.2)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Agent
#
# C51 is a Q-learning algorithm based on DQN. Like DQN, it can be used on any environment with a discrete action space.
#
# The main difference between C51 and DQN is that rather than simply predicting the Q-value for each state-action pair, C51 predicts a histogram model for the probability distribution of the Q-value:
#
# ![Example C51 Distribution](https://github.com/tensorflow/agents/blob/master/docs/tutorials/images/c51_distribution.png?raw=1)
#
# By learning the distribution rather than simply the expected value, the algorithm is able to stay more stable during training, leading to improved final performance. This is particularly true in situations with bimodal or even multimodal value distributions, where a single average does not provide an accurate picture.
#
# In order to train on probability distributions rather than on values, C51 must perform some complex distributional computations in order to calculate its loss function. But don't worry, all of this is taken care of for you in TF-Agents!
#
# To create a C51 Agent, we first need to create a `CategoricalQNetwork`. The API of the `CategoricalQNetwork` is the same as that of the `QNetwork`, except that there is an additional argument `num_atoms`. This represents the number of support points in our probability distribution estimates. (The above image includes 10 support points, each represented by a vertical blue bar.) As you can tell from the name, the default number of atoms is 51.

# %% [markdown]
# We also need an `optimizer` to train the network we just created, and a `train_step_counter` variable to keep track of how many times the network was updated.
#
# Note that one other significant difference from vanilla `DqnAgent` is that we now need to specify `min_q_value` and `max_q_value` as arguments. These specify the most extreme values of the support (in other words, the most extreme of the 51 atoms on either side). Make sure to choose these appropriately for your particular environment.

# %% [markdown]
# One last thing to note is that we also added an argument to use n-step updates with $n$ = 2. In single-step Q-learning ($n$ = 1), we only compute the error between the Q-values at the current time step and the next time step using the single-step return (based on the Bellman optimality equation). The single-step return is defined as:
#
# $G_t = R_{t + 1} + \gamma V(s_{t + 1})$
#
# where we define $V(s) = \max_a{Q(s, a)}$.
#
# N-step updates involve expanding the standard single-step return function $n$ times:
#
# $G_t^n = R_{t + 1} + \gamma R_{t + 2} + \gamma^2 R_{t + 3} + \dots + \gamma^n V(s_{t + n})$
#
# N-step updates enable the agent to bootstrap from further in the future, and with the right value of $n$, this often leads to faster learning.
#
# Although C51 and n-step updates are often combined with prioritized replay to form the core of the [Rainbow agent](https://arxiv.org/pdf/1710.02298.pdf), we saw no measurable improvement from implementing prioritized replay. Moreover, we find that when combining our C51 agent with n-step updates alone, our agent performs as well as other Rainbow agents on the sample of Atari environments we've tested.

# %% [markdown]
# ## Data Collection
#
# As in the DQN tutorial, set up the replay buffer and the initial data collection with the random policy.

# %% [markdown]
# C51 tends to do slightly better than DQN on CartPole-v1, but the difference between the two agents becomes more and more significant in increasingly complex environments. For example, on the full Atari 2600 benchmark, C51 demonstrates a mean score improvement of 126% over DQN after normalizing with respect to a random agent. Additional improvements can be gained by including n-step updates.
#
# For a deeper dive into the C51 algorithm, see [A Distributional Perspective on Reinforcement Learning (2017)](https://arxiv.org/pdf/1707.06887.pdf).

# %%
# Environment setup
env_name = "Acrobot-v1"                                                                # Name of the gym environment
num_iterations = 600                                                                   # Number of iterations (training steps)
initial_collect_steps = 2000                                                           # Number of steps for initial random data collection
collect_steps_per_iteration = 10                                                       # Number of steps collected per iteration
replay_buffer_capacity = 200000                                                        # Maximum capacity of the replay buffer

fc_layer_params = (1000,1000, 1000)                                                      # Neural network architecture: number of neurons in each layer
batch_size = 2000                                                                        # Batch size for training
learning_rate = 5e-5                                                                   # Learning rate for optimizer
gamma = 0.95                                                                          # Discount factor for future rewards
log_interval = 200                                                                     # Interval for logging training progress

num_atoms = 201                                                                        # Number of atoms for Categorical DQN (support points in probability distribution)
min_q_value = -500                                                                     # Minimum Q-value for the distribution
max_q_value = 0                                                                        # Maximum Q-value for the distribution
n_step_update = 5                                                                      # Number of steps for n-step return update

num_eval_episodes = 1                                                                  # Number of episodes to run for evaluation (1 to store individual episode rewards)
eval_interval = 1                                                                      # Evaluate the agent every iteration

# Epsilon decay function for epsilon-greedy policy
def epsilon_fn(step, initial_epsilon=1.0, final_epsilon=0.2, decay_rate=0.999):
    return tf.maximum(final_epsilon, initial_epsilon * (decay_rate**float(step)))     # Gradually decays epsilon over time

# Load the environment
train_py_env = suite_gym.load(env_name)                                                 # Load the environment for training
eval_py_env = suite_gym.load(env_name)                                                  # Load the environment for evaluation

train_env = tf_py_environment.TFPyEnvironment(train_py_env)                             # Convert to TensorFlow environment
eval_env = tf_py_environment.TFPyEnvironment(eval_py_env)                               # Convert to TensorFlow environment for evaluation

# Categorical Q-Network
categorical_q_net = categorical_q_network.CategoricalQNetwork(                          # Define the categorical Q-network
    train_env.observation_spec(),                                                       # Environment observation space
    train_env.action_spec(),                                                            # Environment action space
    num_atoms=num_atoms,                                                                # Number of atoms for probability distribution
    fc_layer_params=fc_layer_params)                                                    # Network architecture (fully connected layers)

# Optimizer with learning rate decay
optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate=learning_rate)               # Define the Adam optimizer

train_step_counter = tf.Variable(0)                                                     # Step counter for training

# Categorical DQN agent initialization
agent = categorical_dqn_agent.CategoricalDqnAgent(                                      # Define the Categorical DQN agent
    train_env.time_step_spec(),                                                         # Environment time step specification
    train_env.action_spec(),                                                            # Environment action specification
    categorical_q_network=categorical_q_net,                                            # Categorical Q-network
    optimizer=optimizer,                                                                # Optimizer
    min_q_value=min_q_value,                                                            # Minimum Q-value
    max_q_value=max_q_value,                                                            # Maximum Q-value
    n_step_update=n_step_update,                                                        # n-step update for return
    td_errors_loss_fn=common.element_wise_squared_loss,                                 # Loss function for TD errors
    gamma=gamma,                                                                        # Discount factor for future rewards
    train_step_counter=train_step_counter,                                              # Step counter
    epsilon_greedy=lambda: epsilon_fn(train_step_counter))                              # Epsilon-greedy policy for exploration

agent.initialize()                                                                      # Initialize the agent

# Create replay buffer using TFUniformReplayBuffer
replay_buffer = tf_uniform_replay_buffer.TFUniformReplayBuffer(                         # Define the replay buffer for storing experience
    data_spec=agent.collect_data_spec,                                                  # Data specification from agent
    batch_size=train_env.batch_size,                                                    # Batch size for replay
    max_length=replay_buffer_capacity)                                                  # Maximum capacity of the replay buffer

# Collect initial random data
random_policy = random_tf_policy.RandomTFPolicy(train_env.time_step_spec(), train_env.action_spec())  # Random policy for initial data collection

# Function to collect a single step of experience
def collect_step(environment, policy):
    time_step = environment.current_time_step()                                         # Get the current time step
    action_step = policy.action(time_step)                                              # Choose an action using the given policy
    next_time_step = environment.step(action_step.action)                               # Take a step in the environment
    traj = trajectory.from_transition(time_step, action_step, next_time_step)           # Create a trajectory from the transition
    replay_buffer.add_batch(traj)                                                       # Add the experience to the replay buffer

# Collect initial random steps to populate the replay buffer
for _ in range(initial_collect_steps):
    collect_step(train_env, random_policy)

# Dataset for sampling from replay buffer
dataset = replay_buffer.as_dataset(                                                     # Create a dataset from the replay buffer
    num_parallel_calls=3, sample_batch_size=batch_size,                                 # Use parallel calls and batch size for sampling
    num_steps=n_step_update + 1).prefetch(3)                                            # Prefetch batches for efficiency
iterator = iter(dataset)                                                                # Create an iterator for the dataset

# Optimize by wrapping in a graph using TF function
agent.train = common.function(agent.train)                                              # Optimize training by wrapping it in a TensorFlow function

# Reset the training step counter
agent.train_step_counter.assign(0)

# Function to run a single episode and collect total rewards
def run_episode(env, policy):
    time_step = env.reset()                                                             # Reset the environment for a new episode
    episode_reward = 0

    while not time_step.is_last():                                                      # Run the episode until it ends
        action_step = policy.action(time_step)                                          # Get an action from the policy
        time_step = env.step(action_step.action)                                        # Take a step in the environment
        episode_reward += time_step.reward.numpy()                                      # Accumulate the reward

    return episode_reward                                                               # Return the total reward for the episode

# Initialize a list to store the total rewards of each episode
episode_rewards = []

# Main training loop
for iteration in range(num_iterations):
    # Collect steps using the agent's collect policy
    for _ in range(collect_steps_per_iteration):
        collect_step(train_env, agent.collect_policy)                                   # Collect data using the agent's collect policy

    # Sample a batch of data from the replay buffer and update the agent
    experience, unused_info = next(iterator)                                            # Sample a batch of experiences
    train_loss = agent.train(experience)                                                # Train the agent using the sampled batch

    step = agent.train_step_counter.numpy()                                             # Get the current training step

    if step % log_interval == 0:                                                        # Log the training loss at regular intervals
        print(f'Episode = {step}: loss = {train_loss.loss}')

    # Evaluate the agent every eval_interval steps
    if step % eval_interval == 0:
        # Run an evaluation episode and store the total reward
        total_reward = run_episode(eval_env, agent.policy)                              # Run a single episode and get the total reward
        episode_rewards.append(total_reward)                                            # Append the reward to the list of episode rewards
        print(f'Episode {step}/{num_iterations}: Total Reward = {total_reward}')
# Out:
# Episode 1/600: Total Reward = [-500.]
# Episode 2/600: Total Reward = [-500.]
# Episode 3/600: Total Reward = [-500.]
# Episode 4/600: Total Reward = [-500.]
# Episode 5/600: Total Reward = [-500.]
# Episode 6/600: Total Reward = [-500.]
# Episode 7/600: Total Reward = [-500.]
# Episode 8/600: Total Reward = [-500.]
# Episode 9/600: Total Reward = [-500.]
# Episode 10/600: Total Reward = [-500.]
# Episode 11/600: Total Reward = [-500.]
# Episode 12/600: Total Reward = [-500.]
# Episode 13/600: Total Reward = [-500.]
# Episode 14/600: Total Reward = [-500.]
# Episode 15/600: Total Reward = [-500.]
# Episode 16/600: Total Reward = [-500.]
# Episode 17/600: Total Reward = [-500.]
# Episode 18/600: Total Reward = [-500.]
# Episode 19/600: Total Reward = [-500.]
# Episode 20/600: Total Reward = [-500.]
# Episode 21/600: Total Reward = [-500.]
# Episode 22/600: Total Reward = [-500.]
# Episode 23/600: Total Reward = [-500.]
# Episode 24/600: Total Reward = [-500.]
# Episode 25/600: Total Reward = [-500.]
# Episode 26/600: Total Reward = [-500.]
# Episode 27/600: Total Reward = [-500.]
# Episode 28/600: Total Reward = [-500.]
# Episode 29/600: Total Reward = [-500.]
# Episode 30/600: Total Reward = [-500.]
# Episode 31/600: Total Reward = [-500.]
# Episode 32/600: Total Reward = [-500.]
# Episode 33/600: Total Reward = [-500.]
# Episode 34/600: Total Reward = [-500.]
# Episode 35/600: Total Reward = [-500.]
# Episode 36/600: Total Reward = [-500.]
# Episode 37/600: Total Reward = [-500.]
# Episode 38/600: Total Reward = [-500.]
# Episode 39/600: Total Reward = [-500.]
# Episode 40/600: Total Reward = [-500.]
# Episode 41/600: Total Reward = [-500.]
# Episode 42/600: Total Reward = [-500.]
# Episode 43/600: Total Reward = [-500.]
# Episode 44/600: Total Reward = [-500.]
# Episode 45/600: Total Reward = [-500.]
# Episode 46/600: Total Reward = [-500.]
# Episode 47/600: Total Reward = [-500.]
# Episode 48/600: Total Reward = [-500.]
# Episode 49/600: Total Reward = [-500.]
# Episode 50/600: Total Reward = [-500.]
# Episode 51/600: Total Reward = [-500.]
# Episode 52/600: Total Reward = [-500.]
# Episode 53/600: Total Reward = [-500.]
# Episode 54/600: Total Reward = [-500.]
# Episode 55/600: Total Reward = [-500.]
# Episode 56/600: Total Reward = [-500.]
# Episode 57/600: Total Reward = [-500.]
# Episode 58/600: Total Reward = [-500.]
# Episode 59/600: Total Reward = [-500.]
# Episode 60/600: Total Reward = [-500.]
# Episode 61/600: Total Reward = [-500.]
# Episode 62/600: Total Reward = [-500.]
# Episode 63/600: Total Reward = [-500.]
# Episode 64/600: Total Reward = [-500.]
# Episode 65/600: Total Reward = [-500.]
# Episode 66/600: Total Reward = [-500.]
# Episode 67/600: Total Reward = [-500.]
# Episode 68/600: Total Reward = [-500.]
# Episode 69/600: Total Reward = [-500.]
# Episode 70/600: Total Reward = [-500.]
# Episode 71/600: Total Reward = [-500.]
# Episode 72/600: Total Reward = [-500.]
# Episode 73/600: Total Reward = [-500.]
# Episode 74/600: Total Reward = [-500.]
# Episode 75/600: Total Reward = [-500.]
# Episode 76/600: Total Reward = [-500.]
# Episode 77/600: Total Reward = [-500.]
# Episode 78/600: Total Reward = [-500.]
# Episode 79/600: Total Reward = [-500.]
# Episode 80/600: Total Reward = [-500.]
# Episode 81/600: Total Reward = [-500.]
# Episode 82/600: Total Reward = [-500.]
# Episode 83/600: Total Reward = [-500.]
# Episode 84/600: Total Reward = [-500.]
# Episode 85/600: Total Reward = [-500.]
# Episode 86/600: Total Reward = [-500.]
# Episode 87/600: Total Reward = [-500.]
# Episode 88/600: Total Reward = [-500.]
# Episode 89/600: Total Reward = [-500.]
# Episode 90/600: Total Reward = [-500.]
# Episode 91/600: Total Reward = [-500.]
# Episode 92/600: Total Reward = [-500.]
# Episode 93/600: Total Reward = [-500.]
# Episode 94/600: Total Reward = [-500.]
# Episode 95/600: Total Reward = [-500.]
# Episode 96/600: Total Reward = [-500.]
# Episode 97/600: Total Reward = [-500.]
# Episode 98/600: Total Reward = [-500.]
# Episode 99/600: Total Reward = [-500.]
# Episode 100/600: Total Reward = [-500.]
# Episode 101/600: Total Reward = [-500.]
# Episode 102/600: Total Reward = [-500.]
# Episode 103/600: Total Reward = [-500.]
# Episode 104/600: Total Reward = [-500.]
# Episode 105/600: Total Reward = [-500.]
# Episode 106/600: Total Reward = [-500.]
# Episode 107/600: Total Reward = [-500.]
# Episode 108/600: Total Reward = [-500.]
# Episode 109/600: Total Reward = [-500.]
# Episode 110/600: Total Reward = [-500.]
# Episode 111/600: Total Reward = [-500.]
# Episode 112/600: Total Reward = [-500.]
# Episode 113/600: Total Reward = [-500.]
# Episode 114/600: Total Reward = [-500.]
# Episode 115/600: Total Reward = [-500.]
# Episode 116/600: Total Reward = [-500.]
# Episode 117/600: Total Reward = [-500.]
# Episode 118/600: Total Reward = [-500.]
# Episode 119/600: Total Reward = [-500.]
# Episode 120/600: Total Reward = [-500.]
# Episode 121/600: Total Reward = [-500.]
# Episode 122/600: Total Reward = [-500.]
# Episode 123/600: Total Reward = [-500.]
# Episode 124/600: Total Reward = [-500.]
# Episode 125/600: Total Reward = [-500.]
# Episode 126/600: Total Reward = [-500.]
# Episode 127/600: Total Reward = [-500.]
# Episode 128/600: Total Reward = [-500.]
# Episode 129/600: Total Reward = [-500.]
# Episode 130/600: Total Reward = [-500.]
# Episode 131/600: Total Reward = [-500.]
# Episode 132/600: Total Reward = [-500.]
# Episode 133/600: Total Reward = [-500.]
# Episode 134/600: Total Reward = [-500.]
# Episode 135/600: Total Reward = [-500.]
# Episode 136/600: Total Reward = [-500.]
# Episode 137/600: Total Reward = [-500.]
# Episode 138/600: Total Reward = [-500.]
# Episode 139/600: Total Reward = [-500.]
# Episode 140/600: Total Reward = [-500.]
# Episode 141/600: Total Reward = [-500.]
# Episode 142/600: Total Reward = [-500.]
# Episode 143/600: Total Reward = [-500.]
# Episode 144/600: Total Reward = [-500.]
# Episode 145/600: Total Reward = [-500.]
# Episode 146/600: Total Reward = [-500.]
# Episode 147/600: Total Reward = [-500.]
# Episode 148/600: Total Reward = [-500.]
# Episode 149/600: Total Reward = [-500.]
# Episode 150/600: Total Reward = [-500.]
# Episode 151/600: Total Reward = [-500.]
# Episode 152/600: Total Reward = [-500.]
# Episode 153/600: Total Reward = [-500.]
# Episode 154/600: Total Reward = [-500.]
# Episode 155/600: Total Reward = [-500.]
# Episode 156/600: Total Reward = [-500.]
# Episode 157/600: Total Reward = [-500.]
# Episode 158/600: Total Reward = [-500.]
# Episode 159/600: Total Reward = [-500.]
# Episode 160/600: Total Reward = [-500.]
# Episode 161/600: Total Reward = [-500.]
# Episode 162/600: Total Reward = [-500.]
# Episode 163/600: Total Reward = [-500.]
# Episode 164/600: Total Reward = [-500.]
# Episode 165/600: Total Reward = [-500.]
# Episode 166/600: Total Reward = [-500.]
# Episode 167/600: Total Reward = [-500.]
# Episode 168/600: Total Reward = [-500.]
# Episode 169/600: Total Reward = [-500.]
# Episode 170/600: Total Reward = [-500.]
# Episode 171/600: Total Reward = [-500.]
# Episode 172/600: Total Reward = [-500.]
# Episode 173/600: Total Reward = [-500.]
# Episode 174/600: Total Reward = [-500.]
# Episode 175/600: Total Reward = [-500.]
# Episode 176/600: Total Reward = [-500.]
# Episode 177/600: Total Reward = [-500.]
# Episode 178/600: Total Reward = [-500.]
# Episode 179/600: Total Reward = [-500.]
# Episode 180/600: Total Reward = [-500.]
# Episode 181/600: Total Reward = [-500.]
# Episode 182/600: Total Reward = [-500.]
# Episode 183/600: Total Reward = [-500.]
# Episode 184/600: Total Reward = [-500.]
# Episode 185/600: Total Reward = [-500.]
# Episode 186/600: Total Reward = [-500.]
# Episode 187/600: Total Reward = [-500.]
# Episode 188/600: Total Reward = [-500.]
# Episode 189/600: Total Reward = [-500.]
# Episode 190/600: Total Reward = [-500.]
# Episode 191/600: Total Reward = [-500.]
# Episode 192/600: Total Reward = [-500.]
# Episode 193/600: Total Reward = [-500.]
# Episode 194/600: Total Reward = [-500.]
# Episode 195/600: Total Reward = [-500.]
# Episode 196/600: Total Reward = [-500.]
# Episode 197/600: Total Reward = [-500.]
# Episode 198/600: Total Reward = [-500.]
# Episode 199/600: Total Reward = [-500.]
# Episode = 200: loss = 1.1931835412979126
# Episode 200/600: Total Reward = [-500.]
# Episode 201/600: Total Reward = [-500.]
# Episode 202/600: Total Reward = [-500.]
# Episode 203/600: Total Reward = [-500.]
# Episode 204/600: Total Reward = [-500.]
# Episode 205/600: Total Reward = [-500.]
# Episode 206/600: Total Reward = [-500.]
# Episode 207/600: Total Reward = [-500.]
# Episode 208/600: Total Reward = [-500.]
# Episode 209/600: Total Reward = [-500.]
# Episode 210/600: Total Reward = [-500.]
# Episode 211/600: Total Reward = [-500.]
# Episode 212/600: Total Reward = [-500.]
# Episode 213/600: Total Reward = [-500.]
# Episode 214/600: Total Reward = [-500.]
# Episode 215/600: Total Reward = [-500.]
# Episode 216/600: Total Reward = [-500.]
# Episode 217/600: Total Reward = [-500.]
# Episode 218/600: Total Reward = [-500.]
# Episode 219/600: Total Reward = [-500.]
# Episode 220/600: Total Reward = [-500.]
# Episode 221/600: Total Reward = [-500.]
# Episode 222/600: Total Reward = [-500.]
# Episode 223/600: Total Reward = [-500.]
# Episode 224/600: Total Reward = [-500.]
# Episode 225/600: Total Reward = [-500.]
# Episode 226/600: Total Reward = [-500.]
# Episode 227/600: Total Reward = [-500.]
# Episode 228/600: Total Reward = [-500.]
# Episode 229/600: Total Reward = [-500.]
# Episode 230/600: Total Reward = [-500.]
# Episode 231/600: Total Reward = [-500.]
# Episode 232/600: Total Reward = [-500.]
# Episode 233/600: Total Reward = [-500.]
# Episode 234/600: Total Reward = [-500.]
# Episode 235/600: Total Reward = [-500.]
# Episode 236/600: Total Reward = [-500.]
# Episode 237/600: Total Reward = [-500.]
# Episode 238/600: Total Reward = [-500.]
# Episode 239/600: Total Reward = [-500.]
# Episode 240/600: Total Reward = [-500.]
# Episode 241/600: Total Reward = [-500.]
# Episode 242/600: Total Reward = [-500.]
# Episode 243/600: Total Reward = [-500.]
# Episode 244/600: Total Reward = [-500.]
# Episode 245/600: Total Reward = [-500.]
# Episode 246/600: Total Reward = [-500.]
# Episode 247/600: Total Reward = [-500.]
# Episode 248/600: Total Reward = [-500.]
# Episode 249/600: Total Reward = [-500.]
# Episode 250/600: Total Reward = [-500.]
# Episode 251/600: Total Reward = [-500.]
# Episode 252/600: Total Reward = [-500.]
# Episode 253/600: Total Reward = [-500.]
# Episode 254/600: Total Reward = [-500.]
# Episode 255/600: Total Reward = [-500.]
# Episode 256/600: Total Reward = [-500.]
# Episode 257/600: Total Reward = [-500.]
# Episode 258/600: Total Reward = [-500.]
# Episode 259/600: Total Reward = [-500.]
# Episode 260/600: Total Reward = [-500.]
# Episode 261/600: Total Reward = [-500.]
# Episode 262/600: Total Reward = [-500.]
# Episode 263/600: Total Reward = [-500.]
# Episode 264/600: Total Reward = [-500.]
# Episode 265/600: Total Reward = [-500.]
# Episode 266/600: Total Reward = [-500.]
# Episode 267/600: Total Reward = [-500.]
# Episode 268/600: Total Reward = [-500.]
# Episode 269/600: Total Reward = [-500.]
# Episode 270/600: Total Reward = [-500.]
# Episode 271/600: Total Reward = [-500.]
# Episode 272/600: Total Reward = [-500.]
# Episode 273/600: Total Reward = [-500.]
# Episode 274/600: Total Reward = [-500.]
# Episode 275/600: Total Reward = [-500.]
# Episode 276/600: Total Reward = [-500.]
# Episode 277/600: Total Reward = [-500.]
# Episode 278/600: Total Reward = [-500.]
# Episode 279/600: Total Reward = [-500.]
# Episode 280/600: Total Reward = [-500.]
# Episode 281/600: Total Reward = [-500.]
# Episode 282/600: Total Reward = [-500.]
# Episode 283/600: Total Reward = [-500.]
# Episode 284/600: Total Reward = [-500.]
# Episode 285/600: Total Reward = [-500.]
# Episode 286/600: Total Reward = [-500.]
# Episode 287/600: Total Reward = [-500.]
# Episode 288/600: Total Reward = [-500.]
# Episode 289/600: Total Reward = [-500.]
# Episode 290/600: Total Reward = [-500.]
# Episode 291/600: Total Reward = [-500.]
# Episode 292/600: Total Reward = [-500.]
# Episode 293/600: Total Reward = [-500.]
# Episode 294/600: Total Reward = [-500.]
# Episode 295/600: Total Reward = [-500.]
# Episode 296/600: Total Reward = [-500.]
# Episode 297/600: Total Reward = [-500.]
# Episode 298/600: Total Reward = [-500.]
# Episode 299/600: Total Reward = [-500.]
# Episode 300/600: Total Reward = [-500.]
# Episode 301/600: Total Reward = [-500.]
# Episode 302/600: Total Reward = [-500.]
# Episode 303/600: Total Reward = [-500.]
# Episode 304/600: Total Reward = [-500.]
# Episode 305/600: Total Reward = [-500.]
# Episode 306/600: Total Reward = [-500.]
# Episode 307/600: Total Reward = [-500.]
# Episode 308/600: Total Reward = [-500.]
# Episode 309/600: Total Reward = [-500.]
# Episode 310/600: Total Reward = [-500.]
# Episode 311/600: Total Reward = [-500.]
# Episode 312/600: Total Reward = [-500.]
# Episode 313/600: Total Reward = [-500.]
# Episode 314/600: Total Reward = [-500.]
# Episode 315/600: Total Reward = [-500.]
# Episode 316/600: Total Reward = [-500.]
# Episode 317/600: Total Reward = [-500.]
# Episode 318/600: Total Reward = [-500.]
# Episode 319/600: Total Reward = [-500.]
# Episode 320/600: Total Reward = [-500.]
# Episode 321/600: Total Reward = [-500.]
# Episode 322/600: Total Reward = [-500.]
# Episode 323/600: Total Reward = [-500.]
# Episode 324/600: Total Reward = [-500.]
# Episode 325/600: Total Reward = [-500.]
# Episode 326/600: Total Reward = [-500.]
# Episode 327/600: Total Reward = [-500.]
# Episode 328/600: Total Reward = [-500.]
# Episode 329/600: Total Reward = [-500.]
# Episode 330/600: Total Reward = [-500.]
# Episode 331/600: Total Reward = [-500.]
# Episode 332/600: Total Reward = [-500.]
# Episode 333/600: Total Reward = [-500.]
# Episode 334/600: Total Reward = [-500.]
# Episode 335/600: Total Reward = [-500.]
# Episode 336/600: Total Reward = [-500.]
# Episode 337/600: Total Reward = [-500.]
# Episode 338/600: Total Reward = [-500.]
# Episode 339/600: Total Reward = [-500.]
# Episode 340/600: Total Reward = [-500.]
# Episode 341/600: Total Reward = [-500.]
# Episode 342/600: Total Reward = [-500.]
# Episode 343/600: Total Reward = [-500.]
# Episode 344/600: Total Reward = [-500.]
# Episode 345/600: Total Reward = [-500.]
# Episode 346/600: Total Reward = [-500.]
# Episode 347/600: Total Reward = [-500.]
# Episode 348/600: Total Reward = [-500.]
# Episode 349/600: Total Reward = [-500.]
# Episode 350/600: Total Reward = [-500.]
# Episode 351/600: Total Reward = [-500.]
# Episode 352/600: Total Reward = [-500.]
# Episode 353/600: Total Reward = [-500.]
# Episode 354/600: Total Reward = [-500.]
# Episode 355/600: Total Reward = [-500.]
# Episode 356/600: Total Reward = [-500.]
# Episode 357/600: Total Reward = [-500.]
# Episode 358/600: Total Reward = [-500.]
# Episode 359/600: Total Reward = [-500.]
# Episode 360/600: Total Reward = [-500.]
# Episode 361/600: Total Reward = [-500.]
# Episode 362/600: Total Reward = [-500.]
# Episode 363/600: Total Reward = [-500.]
# Episode 364/600: Total Reward = [-500.]
# Episode 365/600: Total Reward = [-500.]
# Episode 366/600: Total Reward = [-500.]
# Episode 367/600: Total Reward = [-500.]
# Episode 368/600: Total Reward = [-500.]
# Episode 369/600: Total Reward = [-500.]
# Episode 370/600: Total Reward = [-500.]
# Episode 371/600: Total Reward = [-500.]
# Episode 372/600: Total Reward = [-500.]
# Episode 373/600: Total Reward = [-500.]
# Episode 374/600: Total Reward = [-500.]
# Episode 375/600: Total Reward = [-500.]
# Episode 376/600: Total Reward = [-500.]
# Episode 377/600: Total Reward = [-500.]
# Episode 378/600: Total Reward = [-500.]
# Episode 379/600: Total Reward = [-500.]
# Episode 380/600: Total Reward = [-500.]
# Episode 381/600: Total Reward = [-500.]
# Episode 382/600: Total Reward = [-500.]
# Episode 383/600: Total Reward = [-500.]
# Episode 384/600: Total Reward = [-500.]
# Episode 385/600: Total Reward = [-500.]
# Episode 386/600: Total Reward = [-500.]
# Episode 387/600: Total Reward = [-500.]
# Episode 388/600: Total Reward = [-500.]
# Episode 389/600: Total Reward = [-500.]
# Episode 390/600: Total Reward = [-500.]
# Episode 391/600: Total Reward = [-500.]
# Episode 392/600: Total Reward = [-500.]
# Episode 393/600: Total Reward = [-500.]
# Episode 394/600: Total Reward = [-500.]
# Episode 395/600: Total Reward = [-500.]
# Episode 396/600: Total Reward = [-500.]
# Episode 397/600: Total Reward = [-500.]
# Episode 398/600: Total Reward = [-500.]
# Episode 399/600: Total Reward = [-500.]
# Episode = 400: loss = 0.9126449823379517
# Episode 400/600: Total Reward = [-500.]
# Episode 401/600: Total Reward = [-500.]
# Episode 402/600: Total Reward = [-500.]
# Episode 403/600: Total Reward = [-500.]
# Episode 404/600: Total Reward = [-500.]
# Episode 405/600: Total Reward = [-500.]
# Episode 406/600: Total Reward = [-500.]
# Episode 407/600: Total Reward = [-500.]
# Episode 408/600: Total Reward = [-500.]
# Episode 409/600: Total Reward = [-500.]
# Episode 410/600: Total Reward = [-500.]
# Episode 411/600: Total Reward = [-500.]
# Episode 412/600: Total Reward = [-500.]
# Episode 413/600: Total Reward = [-500.]
# Episode 414/600: Total Reward = [-500.]
# Episode 415/600: Total Reward = [-500.]
# Episode 416/600: Total Reward = [-500.]
# Episode 417/600: Total Reward = [-500.]
# Episode 418/600: Total Reward = [-500.]
# Episode 419/600: Total Reward = [-500.]
# Episode 420/600: Total Reward = [-500.]
# Episode 421/600: Total Reward = [-500.]
# Episode 422/600: Total Reward = [-500.]
# Episode 423/600: Total Reward = [-500.]
# Episode 424/600: Total Reward = [-500.]
# Episode 425/600: Total Reward = [-500.]
# Episode 426/600: Total Reward = [-500.]
# Episode 427/600: Total Reward = [-500.]
# Episode 428/600: Total Reward = [-500.]
# Episode 429/600: Total Reward = [-500.]
# Episode 430/600: Total Reward = [-500.]
# Episode 431/600: Total Reward = [-500.]
# Episode 432/600: Total Reward = [-500.]
# Episode 433/600: Total Reward = [-500.]
# Episode 434/600: Total Reward = [-500.]
# Episode 435/600: Total Reward = [-500.]
# Episode 436/600: Total Reward = [-500.]
# Episode 437/600: Total Reward = [-500.]
# Episode 438/600: Total Reward = [-500.]
# Episode 439/600: Total Reward = [-500.]
# Episode 440/600: Total Reward = [-500.]
# Episode 441/600: Total Reward = [-500.]
# Episode 442/600: Total Reward = [-500.]
# Episode 443/600: Total Reward = [-500.]
# Episode 444/600: Total Reward = [-500.]
# Episode 445/600: Total Reward = [-500.]
# Episode 446/600: Total Reward = [-500.]
# Episode 447/600: Total Reward = [-500.]
# Episode 448/600: Total Reward = [-500.]
# Episode 449/600: Total Reward = [-500.]
# Episode 450/600: Total Reward = [-500.]
# Episode 451/600: Total Reward = [-500.]
# Episode 452/600: Total Reward = [-500.]
# Episode 453/600: Total Reward = [-500.]
# Episode 454/600: Total Reward = [-500.]
# Episode 455/600: Total Reward = [-500.]
# Episode 456/600: Total Reward = [-500.]
# Episode 457/600: Total Reward = [-500.]
# Episode 458/600: Total Reward = [-500.]
# Episode 459/600: Total Reward = [-500.]
# Episode 460/600: Total Reward = [-500.]
# Episode 461/600: Total Reward = [-500.]
# Episode 462/600: Total Reward = [-500.]
# Episode 463/600: Total Reward = [-500.]
# Episode 464/600: Total Reward = [-449.]
# Episode 465/600: Total Reward = [-337.]
# Episode 466/600: Total Reward = [-500.]
# Episode 467/600: Total Reward = [-500.]
# Episode 468/600: Total Reward = [-500.]
# Episode 469/600: Total Reward = [-500.]
# Episode 470/600: Total Reward = [-500.]
# Episode 471/600: Total Reward = [-500.]
# Episode 472/600: Total Reward = [-500.]
# Episode 473/600: Total Reward = [-500.]
# Episode 474/600: Total Reward = [-500.]
# Episode 475/600: Total Reward = [-500.]
# Episode 476/600: Total Reward = [-500.]
# Episode 477/600: Total Reward = [-208.]
# Episode 478/600: Total Reward = [-206.]
# Episode 479/600: Total Reward = [-204.]
# Episode 480/600: Total Reward = [-500.]
# Episode 481/600: Total Reward = [-500.]
# Episode 482/600: Total Reward = [-170.]
# Episode 483/600: Total Reward = [-295.]
# Episode 484/600: Total Reward = [-260.]
# Episode 485/600: Total Reward = [-292.]
# Episode 486/600: Total Reward = [-218.]
# Episode 487/600: Total Reward = [-125.]
# Episode 488/600: Total Reward = [-144.]
# Episode 489/600: Total Reward = [-127.]
# Episode 490/600: Total Reward = [-164.]
# Episode 491/600: Total Reward = [-213.]
# Episode 492/600: Total Reward = [-500.]
# Episode 493/600: Total Reward = [-500.]
# Episode 494/600: Total Reward = [-206.]
# Episode 495/600: Total Reward = [-213.]
# Episode 496/600: Total Reward = [-411.]
# Episode 497/600: Total Reward = [-224.]
# Episode 498/600: Total Reward = [-273.]
# Episode 499/600: Total Reward = [-211.]
# Episode 500/600: Total Reward = [-472.]
# Episode 501/600: Total Reward = [-317.]
# Episode 502/600: Total Reward = [-500.]
# Episode 503/600: Total Reward = [-362.]
# Episode 504/600: Total Reward = [-500.]
# Episode 505/600: Total Reward = [-449.]
# Episode 506/600: Total Reward = [-500.]
# Episode 507/600: Total Reward = [-500.]
# Episode 508/600: Total Reward = [-500.]
# Episode 509/600: Total Reward = [-500.]
# Episode 510/600: Total Reward = [-500.]
# Episode 511/600: Total Reward = [-500.]
# Episode 512/600: Total Reward = [-500.]
# Episode 513/600: Total Reward = [-500.]
# Episode 514/600: Total Reward = [-500.]
# Episode 515/600: Total Reward = [-500.]
# Episode 516/600: Total Reward = [-500.]
# Episode 517/600: Total Reward = [-500.]
# Episode 518/600: Total Reward = [-500.]
# Episode 519/600: Total Reward = [-500.]
# Episode 520/600: Total Reward = [-500.]
# Episode 521/600: Total Reward = [-500.]
# Episode 522/600: Total Reward = [-500.]
# Episode 523/600: Total Reward = [-500.]
# Episode 524/600: Total Reward = [-500.]
# Episode 525/600: Total Reward = [-500.]
# Episode 526/600: Total Reward = [-500.]
# Episode 527/600: Total Reward = [-500.]
# Episode 528/600: Total Reward = [-500.]
# Episode 529/600: Total Reward = [-500.]
# Episode 530/600: Total Reward = [-500.]
# Episode 531/600: Total Reward = [-500.]
# Episode 532/600: Total Reward = [-500.]
# Episode 533/600: Total Reward = [-500.]
# Episode 534/600: Total Reward = [-500.]
# Episode 535/600: Total Reward = [-500.]
# Episode 536/600: Total Reward = [-500.]
# Episode 537/600: Total Reward = [-500.]
# Episode 538/600: Total Reward = [-500.]
# Episode 539/600: Total Reward = [-500.]
# Episode 540/600: Total Reward = [-500.]
# Episode 541/600: Total Reward = [-500.]
# Episode 542/600: Total Reward = [-500.]
# Episode 543/600: Total Reward = [-500.]
# Episode 544/600: Total Reward = [-500.]
# Episode 545/600: Total Reward = [-500.]
# Episode 546/600: Total Reward = [-500.]
# Episode 547/600: Total Reward = [-500.]
# Episode 548/600: Total Reward = [-500.]
# Episode 549/600: Total Reward = [-500.]
# Episode 550/600: Total Reward = [-500.]
# Episode 551/600: Total Reward = [-500.]
# Episode 552/600: Total Reward = [-500.]
# Episode 553/600: Total Reward = [-500.]
# Episode 554/600: Total Reward = [-500.]
# Episode 555/600: Total Reward = [-500.]
# Episode 556/600: Total Reward = [-500.]
# Episode 557/600: Total Reward = [-500.]
# Episode 558/600: Total Reward = [-500.]
# Episode 559/600: Total Reward = [-500.]
# Episode 560/600: Total Reward = [-500.]
# Episode 561/600: Total Reward = [-500.]
# Episode 562/600: Total Reward = [-500.]
# Episode 563/600: Total Reward = [-500.]
# Episode 564/600: Total Reward = [-500.]
# Episode 565/600: Total Reward = [-500.]
# Episode 566/600: Total Reward = [-500.]
# Episode 567/600: Total Reward = [-500.]
# Episode 568/600: Total Reward = [-500.]
# Episode 569/600: Total Reward = [-500.]
# Episode 570/600: Total Reward = [-500.]
# Episode 571/600: Total Reward = [-500.]
# Episode 572/600: Total Reward = [-500.]
# Episode 573/600: Total Reward = [-500.]
# Episode 574/600: Total Reward = [-500.]
# Episode 575/600: Total Reward = [-500.]
# Episode 576/600: Total Reward = [-500.]
# Episode 577/600: Total Reward = [-500.]
# Episode 578/600: Total Reward = [-500.]
# Episode 579/600: Total Reward = [-500.]
# Episode 580/600: Total Reward = [-500.]
# Episode 581/600: Total Reward = [-500.]
# Episode 582/600: Total Reward = [-500.]
# Episode 583/600: Total Reward = [-500.]
# Episode 584/600: Total Reward = [-500.]
# Episode 585/600: Total Reward = [-500.]
# Episode 586/600: Total Reward = [-500.]
# Episode 587/600: Total Reward = [-500.]
# Episode 588/600: Total Reward = [-500.]
# Episode 589/600: Total Reward = [-500.]
# Episode 590/600: Total Reward = [-500.]
# Episode 591/600: Total Reward = [-500.]
# Episode 592/600: Total Reward = [-500.]
# Episode 593/600: Total Reward = [-500.]
# Episode 594/600: Total Reward = [-500.]
# Episode 595/600: Total Reward = [-500.]
# Episode 596/600: Total Reward = [-500.]
# Episode 597/600: Total Reward = [-500.]
# Episode 598/600: Total Reward = [-500.]
# Episode 599/600: Total Reward = [-500.]
# Episode = 600: loss = 0.5292915105819702
# Episode 600/600: Total Reward = [-500.]

# %% [markdown]
# SAVE RETURNS

# %%
# After training loop is finished, save the rewards
import numpy as np

def save_episode_rewards(episode_rewards, file_path):
    np.save(file_path, np.array(episode_rewards))
    print(f"Episode rewards saved at: {file_path}")
save_dir_name = '' #insert saving path
save_episode_rewards(episode_rewards, save_dir_name)
# Out:
# Episode rewards saved at: /content/drive/My Drive/TESI/CLASSIC_DATA/jhonny/jhonny.1000.2000.npy

# %% [markdown]
# VIDEO

# %%
# Set up a virtual display for rendering OpenAI gym environments.
display = pyvirtualdisplay.Display(visible=0, size=(1400, 900)).start()
# Function to embed the video
def embed_mp4(filename):
    """Embeds an mp4 file in the notebook."""
    video = open(filename, 'rb').read()
    b64 = base64.b64encode(video)
    tag = '''
    <video width="640" height="480" controls>
      <source src="data:video/mp4;base64,{0}" type="video/mp4">
    Your browser does not support the video tag.
    </video>'''.format(b64.decode())

    return IPython.display.HTML(tag)

# Start virtual display for rendering
display = pyvirtualdisplay.Display(visible=0, size=(1400, 900)).start()


# Record a late episode (e.g., towards the end of training)
late_episode_filename = 'late_episode.mp4'
with imageio.get_writer(late_episode_filename, fps=60) as video:
    time_step = eval_env.reset()
    video.append_data(eval_py_env.render())  # Capture initial frame
    while not time_step.is_last():
        action_step = agent.policy.action(time_step)
        time_step = eval_env.step(action_step.action)
        video.append_data(eval_py_env.render())  # Capture each frame


# Display the late episode video
print("Late Episode Video:")
IPython.display.display(embed_mp4(late_episode_filename))

# Optional: Save the videos to Google Drive
from google.colab import drive
drive.mount('/content/drive')

late_output_path = '/content/drive/My Drive/TESI/video/late2_episode.mp4'

# !cp {late_episode_filename} {late_output_path}


print(f"Late episode saved at: {late_output_path}")
