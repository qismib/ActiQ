# %% [markdown]
# # layers

# %% [markdown]
# ## classic

# %%
from google.colab import drive
drive.mount('/content/drive')

import numpy as np
import matplotlib.pyplot as plt

# Load the rewards ENTER LOAD PATH


rewards_1 = np.load('').flatten()
rewards_2 = np.load('').flatten()
rewards_3 = np.load('').flatten()
rewards_4 = np.load('').flatten()

def moving_average(data, window_size):
    return np.convolve(data, np.ones(window_size) / window_size, mode='valid')



rewards = [rewards_1, rewards_2, rewards_3, rewards_4]
titles = [
    '32 neurons for each hidden layer',
    '64 neurons for each hidden layer',
    '128 neurons for each hidden layer',
    '256 neurons for each hidden layer'
]
colors = ['#F1C6A0', '#A0CFA0', '#C1A0C1', '#FF5733']

for i in range(4):
    plt.figure(figsize=(12, 6))
    x_values = np.arange(len(moving_average(rewards[i], 2))) * 100
    plt.plot(x_values, moving_average(rewards[i], 2), label=titles[i], color=colors[i], linestyle='-', linewidth=3)
    plt.xlabel('Episode', fontsize=25)
    plt.ylabel('Mean reward', fontsize=25)
    plt.legend(fontsize=20, loc='lower right')
    plt.xlim(0, 20000)
    plt.grid(True)
    plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# comparison

# %%
from google.colab import drive
drive.mount('/content/drive')

import numpy as np
import matplotlib.pyplot as plt

# Load the rewards ENTER LOAD PATH


rewards_1 = np.load('').flatten()
rewards_2 = np.load('').flatten()
rewards_3 = np.load('').flatten()
rewards_4 = np.load('').flatten()


def moving_average(data, window_size):
    return np.convolve(data, np.ones(window_size)/window_size, mode='valid')

plt.figure(figsize=(12, 6))
x_values = np.arange(len(moving_average(rewards_3, 2))) * 100


plt.plot(x_values, moving_average(rewards_1, 2), label='32 neurons for each hidden layer', color='#F1C6A0', linestyle='--', linewidth=2)
plt.plot(x_values, moving_average(rewards_2, 2), label='64 neurons for each hidden layer', color='#A0CFA0', linestyle='--', linewidth=2)
plt.plot(x_values, moving_average(rewards_3, 2), label='128 neurons for each hidden layer', color='#C1A0C1', linestyle='--', linewidth=2)
plt.plot(x_values, moving_average(rewards_4, 2), label='256 neurons for each hidden layer', color='#FF5733', linestyle='-', linewidth=3)


plt.xlabel('Episode', fontsize=18)
plt.ylabel('Mean reward', fontsize=18)


plt.legend(fontsize=18, loc='lower right')
plt.xlim(0, 20000)
plt.grid(True)

plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## quantum

# %%
from google.colab import drive
drive.mount('/content/drive')

import numpy as np
import matplotlib.pyplot as plt

# Load the rewards ENTER LOAD PATH


rewards_1 = np.load('').flatten()
rewards_2 = np.load('').flatten()
rewards_3 = np.load('').flatten()
rewards_4 = np.load('').flatten()


def moving_average(data, window_size):
    return np.convolve(data, np.ones(window_size)/window_size, mode='valid')


rewards = [rewards_1, rewards_2, rewards_3, rewards_4]
titles = ['6 layers', '8 layers', '10 layers', '14 layers']
colors = ['#F1C6A0', 'blue', '#A0CFA0', '#C1A0C1']


for i in range(4):
    plt.figure(figsize=(12, 6))
    x_values = np.arange(len(moving_average(rewards[i], 10)))
    plt.plot(x_values, moving_average(rewards[i], 10), label=titles[i], color=colors[i], linestyle='-', linewidth=3)
    plt.xlabel('Episode', fontsize=25)
    plt.ylabel('Episode reward', fontsize=25)
    plt.legend(fontsize=20)
    plt.xlim(0, 600)
    plt.grid(True)
    plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# comparison

# %%
from google.colab import drive
drive.mount('/content/drive')

import numpy as np
import matplotlib.pyplot as plt

# Load the rewards ENTER LOAD PATH


rewards_1 = np.load('').flatten()
rewards_2 = np.load('').flatten()
rewards_3 = np.load('').flatten()
rewards_4 = np.load('').flatten()

def moving_average(data, window_size):
    return np.convolve(data, np.ones(window_size)/window_size, mode='valid')

plt.figure(figsize=(12, 6))


plt.plot(moving_average(rewards_1, 10), label='6 layers', color='#A0CFA0', linestyle='--', linewidth =2)
plt.plot(moving_average(rewards_2, 10), label='8 layers', color='blue', linestyle='-', linewidth = 3)
plt.plot(moving_average(rewards_3, 10), label='10 layers', color='#C1A0C1', linestyle='--', linewidth = 2)
plt.plot(moving_average(rewards_5, 10), label='14 layers', color='#F1C6A0', linestyle='--', linewidth = 2)


plt.xlabel('Episode', fontsize=18)
plt.ylabel('Episode reward', fontsize=18)


plt.legend(fontsize=18)
plt.xlim(0, 600)
plt.grid(True)

plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # batch

# %% [markdown]
# ## classic

# %%
from google.colab import drive
drive.mount('/content/drive')

import numpy as np
import matplotlib.pyplot as plt

# Load the rewards ENTER LOAD PATH

rewards_1 = np.load('').flatten()
rewards_2 = np.load('').flatten()
rewards_3 = np.load('').flatten()
rewards_4 = np.load('').flatten()

def moving_average(data, window_size):
    return np.convolve(data, np.ones(window_size) / window_size, mode='valid')


rewards = [rewards_1, rewards_2, rewards_3, rewards_4]
labels = ['32 batch size', '64 batch size', '128 batch size', '256 batch size']
colors = ['#A0CFA0', '#FF5733', '#C1A0C1', '#F1C6A0']


for i in range(4):
    plt.figure(figsize=(12, 6))
    x_values = np.arange(len(moving_average(rewards[i], 2))) * 100
    plt.plot(x_values, moving_average(rewards[i], 2), label=labels[i], color=colors[i], linestyle='-', linewidth=3)
    plt.xlabel('Episode', fontsize=25)
    plt.ylabel('Mean reward', fontsize=25)
    plt.legend(fontsize=25)
    plt.xlim(0, 20000)
    plt.grid(True)
    plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# comparison

# %%
from google.colab import drive
drive.mount('/content/drive')

import numpy as np
import matplotlib.pyplot as plt

# Load the rewards ENTER LOAD PATH

rewards_1 = np.load('').flatten()
rewards_2 = np.load('').flatten()
rewards_3 = np.load('').flatten()
rewards_4 = np.load('').flatten()


def moving_average(data, window_size):
    return np.convolve(data, np.ones(window_size)/window_size, mode='valid')

plt.figure(figsize=(12, 6))
x_values = np.arange(len(moving_average(rewards_3, 2))) * 100

plt.plot(x_values, moving_average(rewards_1, 2), label='32 batch size', color='#A0CFA0', linestyle='--', linewidth = 2)
plt.plot(x_values, moving_average(rewards_2, 2), label='64 batch size', color='#FF5733', linestyle='-', linewidth=3)
plt.plot(x_values, moving_average(rewards_3, 2), label='128 batch size', color='#C1A0C1', linestyle='--', linewidth=2)
plt.plot(x_values, moving_average(rewards_4, 2), label='256 batch size', color='#F1C6A0', linestyle='--', linewidth = 2)


plt.xlabel('Episode', fontsize=18)
plt.ylabel('Mean reward', fontsize=18)


plt.legend(fontsize=18, loc='lower right')
plt.xlim(0, 20000)
plt.grid(True)

plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## quantum

# %%
from google.colab import drive
drive.mount('/content/drive')

import numpy as np
import matplotlib.pyplot as plt

# Load the rewards ENTER LOAD PATH

rewards_1 = np.load('').flatten()
rewards_2 = np.load('').flatten()
rewards_3 = np.load('').flatten()
rewards_4 = np.load('').flatten()


def moving_average(data, window_size):
    return np.convolve(data, np.ones(window_size) / window_size, mode='valid')


rewards = [rewards_1, rewards_2, rewards_3, rewards_4]
titles = ['8 batch size', '16 batch size', '32 batch size', '64 batch size']
colors = ['#A0CFA0', '#C1A0C1', 'blue', '#F1C6A0']


for i in range(4):
    plt.figure(figsize=(12, 6))
    x_values = np.arange(len(moving_average(rewards[i], 10)))
    plt.plot(x_values, moving_average(rewards[i], 10), label=titles[i], color=colors[i], linestyle='-', linewidth=3)
    plt.xlabel('Episode', fontsize=25)
    plt.ylabel('Episode reward', fontsize=25)
    plt.legend(fontsize=20)
    plt.xlim(0, 600)
    plt.grid(True)
    plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# comparison

# %%
from google.colab import drive
drive.mount('/content/drive')

import numpy as np
import matplotlib.pyplot as plt

# Load the rewards ENTER LOAD PATH

rewards_1 = np.load('').flatten()
rewards_2 = np.load('').flatten()
rewards_3 = np.load('').flatten()
rewards_4 = np.load('').flatten()

def moving_average(data, window_size):
    return np.convolve(data, np.ones(window_size)/window_size, mode='valid')

plt.figure(figsize=(12, 6))


plt.plot(moving_average(rewards_1, 10), label='8 batch size', color='#A0CFA0', linestyle='--', linewidth = 2)
plt.plot(moving_average(rewards_2, 10), label='16 batch size', color='#C1A0C1', linestyle='--', linewidth = 2)
plt.plot(moving_average(rewards_3, 10), label='32 batch size', color='blue', linestyle='-' ,linewidth =3)
plt.plot(moving_average(rewards_4, 10), label='64 batch size', color='#F1C6A0', linestyle='--', linewidth =2)


plt.xlabel('Episode', fontsize=18)
plt.ylabel('Episode rewards', fontsize=18)


plt.legend(fontsize=18)
plt.xlim(0, 600)
plt.grid(True)

plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Learning rate

# %% [markdown]
# ## classic

# %%
from google.colab import drive
drive.mount('/content/drive')

import numpy as np
import matplotlib.pyplot as plt

# Load the rewards ENTER LOAD PATH

rewards_1 = np.load('').flatten()
rewards_2 = np.load('').flatten()
rewards_3 = np.load('').flatten()
rewards_4 = np.load('').flatten()

def moving_average(data, window_size):
    return np.convolve(data, np.ones(window_size) / window_size, mode='valid')


rewards = [rewards_0, rewards_2, rewards_3, rewards_4]
labels = ['1e-4 learning rate', '5e-5 learning rate', '3e-5 learning rate', '8e-5 learning rate']
colors = ['#A0CFA0', '#FF5733', '#C1A0C1', '#F1C6A0']

for i in range(4):
    plt.figure(figsize=(12, 6))
    x_values = np.arange(len(moving_average(rewards[i], 2))) * 100
    plt.plot(x_values, moving_average(rewards[i], 2), label=labels[i], color=colors[i], linestyle='-', linewidth=3)
    plt.xlabel('Episode', fontsize=25)
    plt.ylabel('Mean reward', fontsize=25)
    plt.legend(fontsize=25)
    plt.xlim(0, 20000)
    plt.grid(True)
    plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# comparison

# %%
from google.colab import drive
drive.mount('/content/drive')

import numpy as np
import matplotlib.pyplot as plt

# Load the rewards ENTER LOAD PATH

rewards_1 = np.load('').flatten()
rewards_2 = np.load('').flatten()
rewards_3 = np.load('').flatten()
rewards_4 = np.load('').flatten()

def moving_average(data, window_size):
    return np.convolve(data, np.ones(window_size)/window_size, mode='valid')

plt.figure(figsize=(12, 6))
x_values = np.arange(len(moving_average(rewards_3, 2))) * 100

plt.plot(x_values, moving_average(rewards_3, 2), label='3e-5 learning rate', color='#C1A0C1', linestyle='--', linewidth=2)
plt.plot(x_values, moving_average(rewards_2, 2), label='5e-5 learning rate', color='#FF5733', linestyle='-', linewidth=3)
plt.plot(x_values, moving_average(rewards_4, 2), label='8e-5 learning rate', color='#F1C6A0', linestyle='--', linewidth=2)
plt.plot(x_values, moving_average(rewards_0, 2), label='1e-4 learning rate', color='#A0CFA0', linestyle='--',linewidth=2)


plt.xlabel('Episode', fontsize=18)
plt.ylabel('Mean reward', fontsize=18)


plt.legend(fontsize=18)
plt.xlim(0, 20000)
plt.grid(True)

plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## quantum

# %%
from google.colab import drive
drive.mount('/content/drive')

import numpy as np
import matplotlib.pyplot as plt

# Load the rewards ENTER LOAD PATH

rewards_1 = np.load('').flatten()
rewards_2 = np.load('').flatten()
rewards_3 = np.load('').flatten()
rewards_4 = np.load('').flatten()

def moving_average(data, window_size):
    return np.convolve(data, np.ones(window_size)/window_size, mode='valid')


rewards = [rewards_1, rewards_2, rewards_3, rewards_4]
labels = ['0.95e-4 learning rate', '1.00e-4 learning rate', '1.02e-4 learning rate', '1.05e-4 learning rate']
colors = ['#A0CFA0', 'blue', '#C1A0C1', '#F1C6A0']


for i in range(4):
    plt.figure(figsize=(12, 6))
    x_values = np.arange(len(moving_average(rewards[i], 10)))
    plt.plot(x_values, moving_average(rewards[i], 10), label=labels[i], color=colors[i], linestyle='-', linewidth=3)
    plt.xlabel('Episode', fontsize=25)
    plt.ylabel('Episode reward', fontsize=25)
    plt.legend(fontsize=25)
    plt.xlim(0, 600)
    plt.grid(True)
    plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# comparison

# %%
from google.colab import drive
drive.mount('/content/drive')

import numpy as np
import matplotlib.pyplot as plt

# Load the rewards ENTER LOAD PATH

rewards_1 = np.load('').flatten()
rewards_2 = np.load('').flatten()
rewards_3 = np.load('').flatten()
rewards_4 = np.load('').flatten()

def moving_average(data, window_size):
    return np.convolve(data, np.ones(window_size)/window_size, mode='valid')

plt.figure(figsize=(12, 6))


plt.plot(moving_average(rewards_1, 10), label='0.95e-4 learning rate', color='#A0CFA0', linestyle='--', linewidth = 2)
plt.plot(moving_average(rewards_2, 10), label='1.00e-4 learning rate', color='blue', linestyle='-', linewidth = 3)
plt.plot(moving_average(rewards_3, 10), label='1.02e-4 learning rate', color='#C1A0C1', linestyle='--' ,linewidth = 2)
plt.plot(moving_average(rewards_4, 10), label='1.05e-4 learning rate', color='#F1C6A0', linestyle='--', linewidth = 2 )



plt.xlabel('Episode', fontsize=18)
plt.ylabel('Episode reward', fontsize=18)


plt.legend(fontsize=18)
plt.xlim(0, 600)
plt.grid(True)

plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # TOT COMPARISON

# %%
from google.colab import drive
drive.mount('/content/drive')

import numpy as np
import matplotlib.pyplot as plt


# Load the rewards ENTER LOAD PATH

rewards_0 = np.load('').flatten()
rewards_1 = np.load('').flatten()
def moving_average(data, window_size):
    return np.convolve(data, np.ones(window_size)/window_size, mode='valid')

plt.figure(figsize=(12, 6))


plt.plot(moving_average(rewards_0, 10), label='Classic run', color='#FF5733', linestyle='-')
plt.plot(moving_average(rewards_1, 10), label='Quantum run', color='blue', linestyle='-')


plt.xlabel('Episode', fontsize=18)
plt.ylabel('Episode reward', fontsize=18)


plt.legend(fontsize=18)
plt.xlim(0, 600)
plt.grid(True)

plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
